# %%
# %pip install --no-cache-dir build
dbutils.library.restartPython()
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %sh
python -m build --wheel
# Out:
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools >= 40.8.0
# * Getting build dependencies for wheel...
# running egg_info
# writing cdp_dq_framework.egg-info/PKG-INFO
# writing dependency_links to cdp_dq_framework.egg-info/dependency_links.txt
# writing requirements to cdp_dq_framework.egg-info/requires.txt
# writing top-level names to cdp_dq_framework.egg-info/top_level.txt
# reading manifest file 'cdp_dq_framework.egg-info/SOURCES.txt'
# writing manifest file 'cdp_dq_framework.egg-info/SOURCES.txt'
# * Installed build dependency versions:
#   - setuptools==84.0.0
# * Building wheel...
# running bdist_wheel
# running build
# running build_py
# copying cdp_dq_framework/utils.py -> build/lib/cdp_dq_framework
# copying cdp_dq_framework/contract.py -> build/lib/cdp_dq_framework
# running egg_info
# writing cdp_dq_framework.egg-info/PKG-INFO
# writing dependency_links to cdp_dq_framework.egg-info/dependency_links.txt
# ...
